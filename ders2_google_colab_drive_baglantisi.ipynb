# %% [markdown]
# İGU SEM 2. OTONOM SİSTEMLER EĞİTİMİ
#
# Bu kod bloğu üzerinde google drive ile google colab platformlarının eşleşmesi sağlanmaktadır.Eşleşme sırasında drive alanında "os.chdir()" fonksiyonu içerisindeki dosyanın adı '/content/drive/My Drive/IGUSEM_OTONOM' olmalıdır
#
# Yavuz Selim Korkmaz
# Eğitmen : Öğr. Gör. Ali ÇETİNKAYA
# 20.01.2026

# %%
print("merhaba igüsem eğitim")
# Out:
# merhaba igüsem eğitim

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/IGUSEM_OTONOM')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/IGUSEM_OTONOM
